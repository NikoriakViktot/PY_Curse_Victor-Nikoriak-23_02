# %% [markdown]
# У вас є ресторан.
#
# офіціанти отримують чайові
#
# менеджер хоче знати:
#
# скільки заробив кожен офіціант
#
# хто лідер
#
# які дні найприбутковіші

# %% [markdown]
# Крок 1 — завантажуємо дані

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# Крок 2 — список офіціантів (list)

# %%
waiters = ["Anna", "Bob", "Mike", "Sara"]

# %% [markdown]
# Крок 3 — касовий апарат (tuple)

# %%
orders = [
    ("Anna", 50, 8),
    ("Bob", 30, 5),
    ("Mike", 70, 10),
    ("Anna", 40, 6),
    ("Sara", 90, 15),
]
